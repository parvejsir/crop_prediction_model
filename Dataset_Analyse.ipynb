# %%
# import require library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Use read_excel instead of read_csv for .xlsx files
dataset = pd.read_excel(r"garden_crops_environment_with_units.xlsx")

# %%
# Display the first 3 rows of the dataset
dataset.head(25)
# Out:
#     Temperature (°C)  Humidity (%)  Soil Moisture (%)    pH  \
# 0              18.10         73.10              37.07  6.27
# 1              18.81         79.12              25.59  6.10
# 2              23.61         79.97              21.44  6.63
# 3              19.70         76.63              38.63  6.40
# 4              20.68         73.90              26.91  6.60
# 5              21.14         71.86              23.44  6.25
# 6              22.70         73.97              30.74  6.36
# 7              22.95         79.17              36.10  6.43
# 8              19.70         77.89              21.51  6.72
# 9              21.07         78.28              23.08  6.40
# 10             21.82         78.91              36.61  6.14
# 11             22.60         71.35              22.38  6.43
# 12             23.59         73.20              29.86  6.81
# 13             18.35         70.31              26.91  6.79
# 14             20.77         71.21              38.24  6.17
# ...

# %%
dataset["Crop Name"].unique()
# Out:
# array(['Rose', 'Daisy', 'Jasmine', 'Sunflower', 'Tomato', 'Lemon',
#        'Lavender', 'Basil', 'Mint', 'Coriander', 'Thyme', 'Orchid',
#        'Petunia', 'Chrysanthemum', 'Tulip', 'Zinnia', 'Marigold',
#        'Aloe Vera', 'Fern', 'Peony', 'Hibiscus', 'Begonia', 'Dahlia',
#        'Geranium', 'Carnation'], dtype=object)

# %%
sns.pairplot(data=dataset,hue="Crop Name")
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset["Crop Name"]
y
# Out:
# 0             Rose
# 1             Rose
# 2             Rose
# 3             Rose
# 4             Rose
#            ...
# 62495    Carnation
# 62496    Carnation
# 62497    Carnation
# 62498    Carnation
# 62499    Carnation
# Name: Crop Name, Length: 62500, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
# ovr
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
lr=LogisticRegression(multi_class="ovr")
lr.fit(x_train,y_train)
# Out:
# c:\Users\wwwad\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\wwwad\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(multi_class='ovr')

# %%
lr.score(x_test,y_test)
crops=lr.predict_proba([[15.92,49.86,31.97,78.64]])
# Out:
# c:\Users\wwwad\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 lr.score(x_test,y_test)
# ----> 2 crops=lr.predict_proba([[15.92,49.86,31.97,78.64]])
#
# File c:\Users\wwwad\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:1431, in LogisticRegression.predict_proba(self, X)
#    1423 ovr = self.multi_class in ["ovr", "warn"] or (
#    1424     self.multi_class in ["auto", "deprecated"]
#    1425     and (
#    (...)
#    1428     )
#    1429 )
#    1430 if ovr:
# -> 1431     return super()._predict_proba_lr(X)
#    1432 else:
#    1433     decision = self.decision_function(X)
#
# ...
